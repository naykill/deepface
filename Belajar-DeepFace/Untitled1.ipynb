# %%
# !pip install deepface

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2
import pandas as pd
# Out:
# WARNING:tensorflow:From C:\Users\irsan\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def verify(img1_path, img2_path, model_name = "VGG-Face"):
    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)
    plt.imshow(img1[:, :, ::-1])
    plt.show()
    plt.imshow(img2[:, :, ::-1])
    plt.show()

    result = DeepFace.verify(img1_path, img2_path, model_name = model_name)
    print("result:",result)
    
    verification = result ['verified']
    if verification:
        print("sama")
    else:
        print("beda")

# %%
verify("img20.jpg", "img24.jpg", model_name = "Facenet")
# Out:
# result: {'verified': False, 'distance': 0.9198096588313885, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 267, 'y': 108, 'w': 364, 'h': 364, 'left_eye': (520, 250), 'right_eye': (387, 262)}, 'img2': {'x': 298, 'y': 235, 'w': 653, 'h': 653, 'left_eye': (741, 477), 'right_eye': (475, 492)}}, 'time': 10.89}
# beda

# %%
verify("img21.jpg", "img20.jpg", model_name = "VGG-Face")
# Out:
# result: {'verified': True, 'distance': 0.20340853621358934, 'threshold': 0.68, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 71, 'y': 85, 'w': 269, 'h': 269, 'left_eye': None, 'right_eye': None}, 'img2': {'x': 267, 'y': 108, 'w': 364, 'h': 364, 'left_eye': (520, 250), 'right_eye': (387, 262)}}, 'time': 11.48}
# sama

# %%
df = DeepFace.find(img_path='img20.jpg', db_path='../Database')
# Out:
# 24-09-05 10:49:17 - Searching img20.jpg in 71 length datastore
# 24-09-05 10:49:18 - find function duration 1.4473340511322021 seconds

# %%
df
# Out:
# [                identity                                      hash  target_x  \
#  0  ../Database\img20.jpg  ba0281eec851a8e9ee872306d921721aa05018c7       267
#  1  ../Database\img21.jpg  573e47ab02268fc263d16264ab274f7556d89d8b        71
#
#     target_y  target_w  target_h  source_x  source_y  source_w  source_h  \
#  0       108       364       364       267       108       364       364
#  1        85       269       269       267       108       364       364
#
#     threshold  distance
#  0       0.68  0.000000
#  1       0.68  0.203409  ]

# %%
obj = DeepFace.analyze(img_path='img20.jpg')
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:23<00:00,  5.98s/it]

# %%
obj
# Out:
# [{'emotion': {'angry': 2.168775368666377e-05,
#    'disgust': 3.766437309488423e-14,
#    'fear': 0.00010434423014731097,
#    'happy': 97.28783352898559,
#    'sad': 5.406786025868431e-05,
#    'surprise': 1.7236678957145153,
#    'neutral': 0.9883243248357967},
#   'dominant_emotion': 'happy',
#   'region': {'x': 267,
#    'y': 108,
#    'w': 364,
#    'h': 364,
#    'left_eye': (520, 250),
#    'right_eye': (387, 262)},
#   'face_confidence': 0.9,
#   'age': 27,
#   'gender': {'Woman': 0.009575837611919269, 'Man': 99.99042749404907},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.16653062775731087,
#    'indian': 5.033506825566292,
#    'black': 0.11144004529342055,
#    'white': 14.939436316490173,
#    'middle eastern': 67.71695613861084,
#    'latino hispanic': 12.032132595777512},
#   'dominant_race': 'middle eastern'}]

# %%
DeepFace.stream(db_path='../Database',source=0)
# Out:
# 24-09-05 10:49:43 - Age model is just built
# 24-09-05 10:49:43 - Gender model is just built
# 24-09-05 10:49:43 - Emotion model is just built
# 24-09-05 10:49:43 - VGG-Face is built
# 24-09-05 10:52:01 - Hello, ../Database\img6.jpg
# 24-09-05 10:52:02 - freezed
# 24-09-05 10:52:07 - freeze released
# KeyboardInterrupt
